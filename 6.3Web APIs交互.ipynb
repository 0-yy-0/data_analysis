# %%
import pandas as pd

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27454',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27454/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27454/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27454/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27454',
#   'id': 469738644,
#   'node_id': 'MDU6SXNzdWU0Njk3Mzg2NDQ=',
#   'number': 27454,
#   'title': 'pd.to_datetime() flaw mixed behavior yielding inconsistant results',
#   'user': {'login': 'go2sree',
#    'id': 44897925,
#    'node_id': 'MDQ6VXNlcjQ0ODk3OTI1',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/44897925?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/go2sree',
#    'html_url': 'https://github.com/go2sree',
#    'followers_url': 'https://api.github.com/users/go2sree/followers',
#    'following_url': 'https://api.github.com/users/go2sree/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/go2sree/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/go2sree/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/go2sree/subscriptions',
#    'organizations_url': 'https://api.github.com/users/go2sree/orgs',
#    'repos_url': 'https://api.github.com/users/go2sree/repos',
#    'events_url': 'https://api.github.com/users/go2sree/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/go2sree/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T12:21:11Z',
#   'updated_at': '2019-07-18T12:21:11Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nimport pandas as pd\r\nstr1='05-01-2019 00:37' \r\ndate1=pd.to_datetime(str1).date()\r\nprint(date1)\r\n\r\n# output  2019-05-01\r\n\r\n\r\nstr2='15-01-2019 00:37' \r\ndate2=pd.to_datetime(str2).date()\r\nprint(date2)\r\n\r\n# output   2019-01-15\r\n\r\n```\r\n#### Problem description\r\n\r\npd.to_datetime( ) is giving inconsistant out put,  in the first piece of code where 01 is month and 05 is date after conversion these values have interchanged 01 as date and 05 as month.\r\n\r\nbut for similar code where the string value has 15 as date and 01 as month after conversion remained the same as expected.\r\n\r\nI have tried .astype(‘datetime64’)   and this also yielded the same wrong values as above code\r\n\r\n![image](https://user-images.githubusercontent.com/44897925/61456323-5f86f200-a983-11e9-8648-62e8f05afd0a.png)\r\n\r\n![image](https://user-images.githubusercontent.com/44897925/61456389-88a78280-a983-11e9-86e8-6b3de726cc96.png)\r\n\r\n![image](https://user-images.githubusercontent.com/44897925/61456419-9c52e900-a983-11e9-9d74-0eb3835f6fcd.png)\r\n\r\n\r\nIs this a known Issue and please provide workaround \r\n\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27453',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27453/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27453/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27453/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27453',
#   'id': 469710225,
#   'node_id': 'MDU6SXNzdWU0Njk3MTAyMjU=',
#   'number': 27453,
#   'title': 'Right merge not preserve order',
#   'user': {'login': 'jesrael',
#    'id': 10682573,
#    'node_id': 'MDQ6VXNlcjEwNjgyNTcz',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/10682573?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jesrael',
#    'html_url': 'https://github.com/jesrael',
#    'followers_url': 'https://api.github.com/users/jesrael/followers',
#    'following_url': 'https://api.github.com/users/jesrael/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jesrael/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jesrael/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jesrael/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jesrael/orgs',
#    'repos_url': 'https://api.github.com/users/jesrael/repos',
#    'events_url': 'https://api.github.com/users/jesrael/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jesrael/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T11:12:41Z',
#   'updated_at': '2019-07-18T11:12:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "Base by [SO question](https://stackoverflow.com/q/57092373/2901002):\r\n\r\nMerge with right join not preserve order of columns:\r\n\r\n    columns = ['A', 'B', 'C']\r\n    data_1 = [[2, 5, 3, 5], [8, 2, 4, 1], [6, 5, 9, 1]]\r\n    data_1 = np.array(data_1).T\r\n    df_1 = pd.DataFrame(data=data_1, columns=columns)\r\n    print (df_1)\r\n       A  B  C\r\n    0  2  8  6\r\n    1  5  2  5\r\n    2  3  4  9\r\n    3  5  1  1\r\n    \r\n    columns = ['A', 'B', 'C']\r\n    data_2 = [[2, 5, 3, 5], [7, 1, 3, 0], [np.nan, np.nan, np.nan, np.nan]]\r\n    data_2 = np.array(data_2).T\r\n    df_2 = pd.DataFrame(data=data_2, columns=columns)\r\n    print (df_2)\r\n         A    B   C\r\n    0  2.0  7.0 NaN\r\n    1  5.0  1.0 NaN\r\n    2  3.0  3.0 NaN\r\n    3  5.0  0.0 NaN\r\n    \r\n    #right join NOT preserve order\r\n    df1 = df_1.merge(df_2[['A', 'B']], on=['A', 'B'], how='right')\r\n    print (df1)\r\n       A  B    C\r\n    0  5  1  1.0\r\n    1  2  7  NaN\r\n    2  3  3  NaN\r\n    3  5  0  NaN\r\n    \r\nCorrect order for right join:\r\n        \r\n        A   B   C\r\n    0   2   7   NaN\r\n    1   5   1   1\r\n    2   3   3   NaN\r\n    3   5   0   NaN\r\n    \r\n    #left join wpreserve order correct\r\n    df2 = df_1.merge(df_2[['A', 'B']], on=['A', 'B'], how='left')\r\n    print (df2)\r\n       A  B  C\r\n    0  2  8  6\r\n    1  5  2  5\r\n    2  3  4  9\r\n    3  5  1  1\r\n\r\n\r\n----\r\n\r\n    print (pd.show_versions())\r\n    \r\n    INSTALLED VERSIONS\r\n    ------------------\r\n    commit: None\r\n    python: 3.7.3.final.0\r\n    python-bits: 64\r\n    OS: Windows\r\n    OS-release: 7\r\n    machine: AMD64\r\n    processor: Intel64 Family 6 Model 60 Stepping 3, GenuineIntel\r\n    byteorder: little\r\n    LC_ALL: None\r\n    LANG: en\r\n    LOCALE: None.None\r\n    \r\n    pandas: 0.24.2\r\n    pytest: 4.3.1\r\n    pip: 19.0.3\r\n    setuptools: 40.8.0\r\n    Cython: 0.29.6\r\n    numpy: 1.16.2\r\n    scipy: 1.2.1\r\n    pyarrow: None\r\n    xarray: None\r\n    IPython: 7.4.0\r\n    sphinx: 1.8.5\r\n    patsy: 0.5.1\r\n    dateutil: 2.8.0\r\n    pytz: 2018.9\r\n    blosc: None\r\n    bottleneck: 1.2.1\r\n    tables: 3.5.1\r\n    numexpr: 2.6.9\r\n    feather: None\r\n    matplotlib: 3.0.3\r\n    openpyxl: 2.6.1\r\n    xlrd: 1.2.0\r\n    xlwt: 1.3.0\r\n    xlsxwriter: 1.1.5\r\n    lxml.etree: 4.3.2\r\n    bs4: 4.7.1\r\n    html5lib: 1.0.1\r\n    sqlalchemy: 1.3.1\r\n    pymysql: None\r\n    psycopg2: None\r\n    jinja2: 2.10\r\n    s3fs: None\r\n    fastparquet: None\r\n    pandas_gbq: None\r\n    pandas_datareader: None\r\n    gcsfs: None\r\n    None"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27451',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27451/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27451/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27451/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27451',
#   'id': 469703094,
#   'node_id': 'MDU6SXNzdWU0Njk3MDMwOTQ=',
#   'number': 27451,
#   'title': "`Dataframe.sample()` isn't validating `frac`",
#   'user': {'login': 'ddebernardy',
#    'id': 225259,
#    'node_id': 'MDQ6VXNlcjIyNTI1OQ==',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/225259?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ddebernardy',
#    'html_url': 'https://github.com/ddebernardy',
#    'followers_url': 'https://api.github.com/users/ddebernardy/followers',
#    'following_url': 'https://api.github.com/users/ddebernardy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ddebernardy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ddebernardy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ddebernardy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ddebernardy/orgs',
#    'repos_url': 'https://api.github.com/users/ddebernardy/repos',
#    'events_url': 'https://api.github.com/users/ddebernardy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ddebernardy/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T10:55:17Z',
#   'updated_at': '2019-07-18T10:55:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "Minor/trivial bug:\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/master/pandas/core/generic.py#L4960\r\n\r\nShouldn't `sample()` check that `frac` is between 0 and 1 somewhere?\r\n\r\nDoc improvement suggestion:\r\n\r\nCould anyone confirm that `replace=True|False` means allowing|disallowing sampling the same row more than once?\r\n\r\nMethinks the docs could use an update to make what `replace` does clearer for newcomers - or at least for those who aren't familiar with `numpy`."},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27450',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27450/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27450/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27450/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27450',
#   'id': 469686451,
#   'node_id': 'MDU6SXNzdWU0Njk2ODY0NTE=',
#   'number': 27450,
#   'title': 'Why read_sas is converting strings to float?',
#   'user': {'login': 'SqrtPapere',
#    'id': 17984266,
#    'node_id': 'MDQ6VXNlcjE3OTg0MjY2',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/17984266?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SqrtPapere',
#    'html_url': 'https://github.com/SqrtPapere',
#    'followers_url': 'https://api.github.com/users/SqrtPapere/followers',
#    'following_url': 'https://api.github.com/users/SqrtPapere/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SqrtPapere/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SqrtPapere/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SqrtPapere/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SqrtPapere/orgs',
#    'repos_url': 'https://api.github.com/users/SqrtPapere/repos',
#    'events_url': 'https://api.github.com/users/SqrtPapere/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SqrtPapere/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T10:15:02Z',
#   'updated_at': '2019-07-18T10:15:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "#### Code Sample\r\n```python\r\nimport pandas as pd\r\ndf = pd.read_sas('test.sas7bdat', format='sas7bdat', encoding='utf-8')\r\n\r\n```\r\n#### Problem description\r\n\r\nI am trying to read a `.sas7bdat` file using `read_sas` and I am having a hard time because the module is converting strings values that look like a number into `float`.\r\n\r\nFor example, if I have a telephone number like `'348386789'` and I read it with the code I posted the output obtained is `348386789.0`.\r\n\r\nI noticed the same problem in the `read_csv` function but there you can use the argument `dtype` to manually set the type for each column (es. dtype={'number': str)}).\r\n\r\n#### Expected Output\r\n\r\n`'348386789'`\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.7.2.final.0\r\npython-bits: 64\r\nOS: Windows\r\nOS-release: 10\r\nmachine: AMD64\r\nprocessor: Intel64 Family 6 Model 142 Stepping 9, GenuineIntel\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: None\r\nLOCALE: None.None\r\n\r\npandas: 0.24.2\r\npytest: None\r\npip: 19.1.1\r\nsetuptools: 41.0.0\r\nCython: None\r\nnumpy: 1.16.3\r\nscipy: None\r\npyarrow: 0.13.0\r\nxarray: None\r\nIPython: 7.4.0\r\nsphinx: 2.1.2\r\npatsy: None\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: 3.5.2\r\nnumexpr: 2.6.9\r\nfeather: 0.4.0\r\nmatplotlib: None\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: 4.3.4\r\nbs4: None\r\nhtml5lib: None\r\nsqlalchemy: 1.3.5\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10.1\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27447',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27447/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27447/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27447/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27447',
#   'id': 469571737,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk4NzU2NjY1',
#   'number': 27447,
#   'title': 'WIP: treat list of namedtuples like list of dict in DataFrame()',
#   'user': {'login': 'pilkibun',
#    'id': 51503352,
#    'node_id': 'MDQ6VXNlcjUxNTAzMzUy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/51503352?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pilkibun',
#    'html_url': 'https://github.com/pilkibun',
#    'followers_url': 'https://api.github.com/users/pilkibun/followers',
#    'following_url': 'https://api.github.com/users/pilkibun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pilkibun/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pilkibun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pilkibun/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pilkibun/orgs',
#    'repos_url': 'https://api.github.com/users/pilkibun/repos',
#    'events_url': 'https://api.github.com/users/pilkibun/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pilkibun/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T05:03:33Z',
#   'updated_at': '2019-07-18T05:03:33Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27447',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27447',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27447.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27447.patch'},
#   'body': '- [X] closes #27329\r\n- [ ] tests added / passed \r\n- [X] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27446',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27446/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27446/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27446/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27446',
#   'id': 469566261,
#   'node_id': 'MDU6SXNzdWU0Njk1NjYyNjE=',
#   'number': 27446,
#   'title': 'Is the internal twosigma refactor of window.pyx planned for merging in pandas?',
#   'user': {'login': 'pilkibun',
#    'id': 51503352,
#    'node_id': 'MDQ6VXNlcjUxNTAzMzUy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/51503352?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pilkibun',
#    'html_url': 'https://github.com/pilkibun',
#    'followers_url': 'https://api.github.com/users/pilkibun/followers',
#    'following_url': 'https://api.github.com/users/pilkibun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pilkibun/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pilkibun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pilkibun/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pilkibun/orgs',
#    'repos_url': 'https://api.github.com/users/pilkibun/repos',
#    'events_url': 'https://api.github.com/users/pilkibun/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pilkibun/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T04:35:00Z',
#   'updated_at': '2019-07-18T04:35:20Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': 'I\'ve been thinking of improvements to pandas rolling window functionality. Namely, allowing users to supply their own indexers and allowing numba JIT\'d kernels to be passed to apply/transform.\r\n\r\nI [floated](](https://github.com/pandas-dev/pandas/pull/27403#discussion_r304165649)) the idea of a window.pyx refactor, and was told that "others are working on it". I\'ve seen no issue for this on pandas-dev/pandas, but there\'s apperently an effort going privately at Twosigma to do a major redesign of this part of pandas.\r\n\r\nOf course they\'re free to develop whatever they want internally, but if this is meant for inclusion in pandas, why is the design not being discussed here? and if it\'s an internal effort only (perfectly fine), why should their efforts influence efforts by contributors such as myself?\r\n\r\nI\'d kindly to like to have this clarified before I waste time working on my own PR.\r\nThere seems to be an intention to push [some bits](https://github.com/twosigma/pandas/pull/3#pullrequestreview-258851617) to pandas, but not others ?\r\n\r\n> jreback: I would do this versus pandas/master. Best to push whatever we can there \r\n> in small uncontroversial bits.\r\n \r\nSee https://github.com/pandas-dev/pandas/pull/27305, and https://github.com/twosigma/pandas/issues/4\r\n\r\ncc @jreback , @mroeschke \r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27445',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27445/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27445/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27445/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27445',
#   'id': 469545970,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk4NzM3MTcz',
#   'number': 27445,
#   'title': 'BUG: avoid incorrectly inheriting result',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T02:51:43Z',
#   'updated_at': '2019-07-18T02:51:43Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27445',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27445',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27445.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27445.patch'},
#   'body': "This has caused problems in a number of local branches, but I don't have a good test case on master.  Suggestions welcome.  Still though, the failure mode is pretty clear, so this fixes it."},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27444',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27444/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27444/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27444/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27444',
#   'id': 469544767,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk4NzM2MjYy',
#   'number': 27444,
#   'title': 'CLN: simplify maybe_convery_objects, soft_convert_objects',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T02:46:26Z',
#   'updated_at': '2019-07-18T02:46:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27444',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27444',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27444.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27444.patch'},
#   'body': 'Block.replace has code for dispatching to either maybe_convert_objects or soft_convert_objects, but the former is only reached from the tests.  So rip that out and use soft_convert_objects.\r\n\r\nBoth of the functions have branches that are unreachable, so rip those out, along with adding types and validation.'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27443',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27443/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27443/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27443/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27443',
#   'id': 469530530,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk4NzI2ODM2',
#   'number': 27443,
#   'title': 'TST: Add test for operations on DataFrame with Interval CategoricalIndex',
#   'user': {'login': 'yanglinlee',
#    'id': 6498024,
#    'node_id': 'MDQ6VXNlcjY0OTgwMjQ=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6498024?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanglinlee',
#    'html_url': 'https://github.com/yanglinlee',
#    'followers_url': 'https://api.github.com/users/yanglinlee/followers',
#    'following_url': 'https://api.github.com/users/yanglinlee/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yanglinlee/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yanglinlee/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yanglinlee/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yanglinlee/orgs',
#    'repos_url': 'https://api.github.com/users/yanglinlee/repos',
#    'events_url': 'https://api.github.com/users/yanglinlee/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yanglinlee/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-18T01:43:53Z',
#   'updated_at': '2019-07-18T02:22:32Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27443',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27443',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27443.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27443.patch'},
#   'body': '- [x] closes #27415\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27442',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27442/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27442/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27442/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27442',
#   'id': 469492865,
#   'node_id': 'MDU6SXNzdWU0Njk0OTI4NjU=',
#   'number': 27442,
#   'title': 'Give pandas.core.groupby.generic.DataFrameGroupBy __str__/_repr_pretty_/__repr__ methods',
#   'user': {'login': 'Strilanc',
#    'id': 79941,
#    'node_id': 'MDQ6VXNlcjc5OTQx',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/79941?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Strilanc',
#    'html_url': 'https://github.com/Strilanc',
#    'followers_url': 'https://api.github.com/users/Strilanc/followers',
#    'following_url': 'https://api.github.com/users/Strilanc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Strilanc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Strilanc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Strilanc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Strilanc/orgs',
#    'repos_url': 'https://api.github.com/users/Strilanc/repos',
#    'events_url': 'https://api.github.com/users/Strilanc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Strilanc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-07-17T23:13:12Z',
#   'updated_at': '2019-07-18T01:24:38Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "Current behavior:\r\n\r\n```\r\n>>> df = pd.DataFrame({'a': [1, 1, 3], 'b': [9, 8, 7]})\r\n>>> df.groupby('a')                                                                                                                       \r\n<pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fd3d5a7b470>\r\n```\r\n\r\nDesired behavior (example, not exact):\r\n\r\n```\r\n>>> df = pd.DataFrame({'a': [1, 1, 3], 'b': [9, 8, 7]})\r\n>>> df.groupby('a')\r\ngroup a=1\r\n   a  b\r\n0  1  9\r\n1  1  8\r\n\r\ngroup a=3\r\n   a  b\r\n2  3  7\r\n```"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27439',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27439/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27439/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27439/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27439',
#   'id': 469423730,
#   'node_id': 'MDU6SXNzdWU0Njk0MjM3MzA=',
#   'number': 27439,
#   'title': '[Feature request] Add a "filter" method to Index and Series',
#   'user': {'login': 'jolespin',
#    'id': 9061708,
#    'node_id': 'MDQ6VXNlcjkwNjE3MDg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/9061708?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jolespin',
#    'html_url': 'https://github.com/jolespin',
#    'followers_url': 'https://api.github.com/users/jolespin/followers',
#    'following_url': 'https://api.github.com/users/jolespin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jolespin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jolespin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jolespin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jolespin/orgs',
#    'repos_url': 'https://api.github.com/users/jolespin/repos',
#    'events_url': 'https://api.github.com/users/jolespin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jolespin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-07-17T20:18:34Z',
#   'updated_at': '2019-07-17T21:51:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\n\r\n# Function\r\ndef _filter(self, func):\r\n    return self[list(map(func, self))]\r\n\r\n# Set the attribute\r\nsetattr(pd.Index, "filter", _filter)\r\nindex = pd.Index(["iris_1", "notiris_1", "iris_2", "other_thing"])\r\n\r\n# New way\r\nfunc = lambda x:x.startswith("iris")\r\nprint("New way:", index.filter(func))\r\n\r\n# Old way\r\nprint("Old way:", index[index.map(func)])\r\n\r\n# New way: Index([\'iris_1\', \'iris_2\'], dtype=\'object\')\r\n# Old way: Index([\'iris_1\', \'iris_2\'], dtype=\'object\')\r\n\r\n# Set the attribute\r\nsetattr(pd.Series, "filter", _filter)\r\nseries = pd.Series(list("imagine_more_complex_stuff_here_instead"))\r\n\r\n# New way\r\nfunc = lambda x:x in ["o", "_"]\r\nprint("New way:", series.filter(func))\r\n\r\n# Old way\r\nprint("Old way:", series[series.map(func)])\r\n\r\n# New way: 7     _\r\n# 9     o\r\n# 12    _\r\n# 14    o\r\n# 20    _\r\n# 26    _\r\n# 31    _\r\n# dtype: object\r\n# Old way: 7     _\r\n# 9     o\r\n# 12    _\r\n# 14    o\r\n# 20    _\r\n# 26    _\r\n# 31    _\r\n# dtype: object\r\n```\r\n#### Problem description\r\n\r\nII always find myself writing really verbose code to filter my pandas indices or series.  I love the map method and would like to extend this concept to include `filter`.'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27438',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27438/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27438/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27438/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27438',
#   'id': 469385906,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk4NjIzNzYw',
#   'number': 27438,
#   'title': 'BUG: maybe_convert_objects mixed datetimes and timedeltas ',
#   'user': {'login': 'BeforeFlight',
#    'id': 19474336,
#    'node_id': 'MDQ6VXNlcjE5NDc0MzM2',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/19474336?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BeforeFlight',
#    'html_url': 'https://github.com/BeforeFlight',
#    'followers_url': 'https://api.github.com/users/BeforeFlight/followers',
#    'following_url': 'https://api.github.com/users/BeforeFlight/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/BeforeFlight/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/BeforeFlight/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/BeforeFlight/subscriptions',
#    'organizations_url': 'https://api.github.com/users/BeforeFlight/orgs',
#    'repos_url': 'https://api.github.com/users/BeforeFlight/repos',
#    'events_url': 'https://api.github.com/users/BeforeFlight/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/BeforeFlight/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric',
#     'name': 'Numeric',
#     'color': '006b75',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 7,
#   'created_at': '2019-07-17T18:47:51Z',
#   'updated_at': '2019-07-17T23:55:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27438',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27438',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27438.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27438.patch'},
#   'body': '- [X] corresponding [discussion](https://github.com/pandas-dev/pandas/issues/27417#issuecomment-512014358) 27417\r\n- [ ] tests added / passed\r\n- [X] passes `black pandas`\r\n- [X] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\nIn order to stick to `maybe_convert_objects` realization it was needed to introduce `Seen().nat_` param. Since we want to distinguish following situations: were seen `NaT` or `datetime` or `timedelta`\r\n\r\nNOTE: in current realization array full of `NaT` will be converted to `np.datetime64`.'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27437',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27437/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27437/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27437/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27437',
#   'id': 469374615,
#   'node_id': 'MDU6SXNzdWU0NjkzNzQ2MTU=',
#   'number': 27437,
#   'title': 'Indexing on series where index is output from pd.cut ',
#   'user': {'login': 'kuchenrolle',
#    'id': 20798845,
#    'node_id': 'MDQ6VXNlcjIwNzk4ODQ1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/20798845?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kuchenrolle',
#    'html_url': 'https://github.com/kuchenrolle',
#    'followers_url': 'https://api.github.com/users/kuchenrolle/followers',
#    'following_url': 'https://api.github.com/users/kuchenrolle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kuchenrolle/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kuchenrolle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kuchenrolle/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kuchenrolle/orgs',
#    'repos_url': 'https://api.github.com/users/kuchenrolle/repos',
#    'events_url': 'https://api.github.com/users/kuchenrolle/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kuchenrolle/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-17T18:24:13Z',
#   'updated_at': '2019-07-17T18:24:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndata = pd.DataFrame(dict(values=range(20), quintiles=pd.cut(range(20), 5)))\r\ngrouped = data.groupby("quintiles")["values"]\r\nsamples = grouped.agg(lambda x: list(x.sample(3)))\r\n\r\nsamples\r\n# quintiles\r\n# (-0.019, 3.8]       [3, 2, 1]\r\n# (3.8, 7.6]          [7, 4, 6]\r\n# (7.6, 11.4]       [8, 10, 11]\r\n# (11.4, 15.2]     [15, 14, 12]\r\n# (15.2, 19.0]     [17, 16, 19]\r\n# Name: values, dtype: object\r\n\r\nsamples[0]\r\n# [3, 2, 1]\r\nsamples[1]\r\n# [3, 2, 1]\r\nsamples[2.3]\r\n# [3, 2, 1]\r\nsamples[19]\r\n# [17, 16, 19]\r\n\r\nsamples.keys()\r\n# CategoricalIndex([(-0.019, 3.8], (3.8, 7.6], (7.6, 11.4], (11.4, 15.2],\r\n#                   (15.2, 19.0]],\r\n#                  categories=[(-0.019, 3.8], (3.8, 7.6], (7.6, 11.4], (11.4, 15.2], (15.2, 19.0]], ordered=True, name=\'quintiles\', dtype=\'category\')\r\n```\r\n#### Problem description\r\nIndexing a series object that has pd.cut() intervals as its index results in membership test of the provided index on the intervals, which I found interesting, but it was very unexpected. Is this intentional and documented somewhere? When I give the labels names (labels=list("abcde") in pd.cut), this doesn\'t happen anymore.\r\n\r\n#### Expected Output\r\nI expectived it to fall back on .iloc[].\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.7.3.final.0\r\npython-bits: 64\r\nOS: Linux\r\nOS-release: 3.10.0-957.12.2.el7.x86_64\r\nmachine: x86_64\r\nprocessor: x86_64\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_GB.UTF-8\r\nLOCALE: en_GB.UTF-8\r\n\r\npandas: 0.24.2\r\npytest: 4.4.1\r\npip: 19.1.1\r\nsetuptools: 41.0.1\r\nCython: 0.29.6\r\nnumpy: 1.16.3\r\nscipy: 1.2.1\r\npyarrow: None\r\nxarray: 0.12.1\r\nIPython: 7.4.0\r\nsphinx: None\r\npatsy: 0.5.1\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: None\r\nnumexpr: None\r\nfeather: None\r\nmatplotlib: 3.1.0\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: 4.3.3\r\nbs4: 4.7.1\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n\r\n</details>\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27436',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27436/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27436/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27436/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27436',
#   'id': 469371508,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk4NjEzMzQ1',
#   'number': 27436,
#   'title': 'BUG: fix+test quantile with empty DataFrame, closes #23925',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False},
#    {'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False},
#    {'id': 1049312478,
#     'node_id': 'MDU6TGFiZWwxMDQ5MzEyNDc4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/DataFrame',
#     'name': 'DataFrame',
#     'color': '370f77',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-17T18:17:01Z',
#   'updated_at': '2019-07-17T23:56:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27436',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27436',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27436.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27436.patch'},
#   'body': '- [x] closes #23925\r\n- [x] tests added / passed\r\n- [x] passes `black pandas`\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27435',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27435/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27435/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27435/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27435',
#   'id': 469368371,
#   'node_id': 'MDU6SXNzdWU0NjkzNjgzNzE=',
#   'number': 27435,
#   'title': 'Version 0.24.2 is suddenly Python 3 only. I was under the impression that 0.24.x supports both Python 2 and 3.',
#   'user': {'login': 'didip',
#    'id': 72918,
#    'node_id': 'MDQ6VXNlcjcyOTE4',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/72918?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/didip',
#    'html_url': 'https://github.com/didip',
#    'followers_url': 'https://api.github.com/users/didip/followers',
#    'following_url': 'https://api.github.com/users/didip/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/didip/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/didip/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/didip/subscriptions',
#    'organizations_url': 'https://api.github.com/users/didip/orgs',
#    'repos_url': 'https://api.github.com/users/didip/repos',
#    'events_url': 'https://api.github.com/users/didip/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/didip/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 12,
#   'created_at': '2019-07-17T18:09:20Z',
#   'updated_at': '2019-07-17T21:44:39Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```bash\r\nRuntimeError: Python version >= 3.5 required.\r\n```\r\n#### Problem description\r\n\r\nUnder this docs: https://pandas.pydata.org/pandas-docs/stable/whatsnew/v0.24.0.html\r\n\r\n0.24.x is supposed to be backward compatible to Python 2.\r\n\r\n```\r\nThe 0.24.x series of releases will be the last to support Python 2. Future feature releases will support Python 3 only. See Plan for dropping Python 2.7 for more details\r\n```\r\n\r\n#### Expected Output\r\n\r\n0.24.2 should still work on Python 2.\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27431',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27431/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27431/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27431/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27431',
#   'id': 469247535,
#   'node_id': 'MDU6SXNzdWU0NjkyNDc1MzU=',
#   'number': 27431,
#   'title': 'Feature request: add option to disable columns.levels autosorting',
#   'user': {'login': 'MCM-Math',
#    'id': 20364547,
#    'node_id': 'MDQ6VXNlcjIwMzY0NTQ3',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/20364547?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MCM-Math',
#    'html_url': 'https://github.com/MCM-Math',
#    'followers_url': 'https://api.github.com/users/MCM-Math/followers',
#    'following_url': 'https://api.github.com/users/MCM-Math/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MCM-Math/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MCM-Math/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MCM-Math/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MCM-Math/orgs',
#    'repos_url': 'https://api.github.com/users/MCM-Math/repos',
#    'events_url': 'https://api.github.com/users/MCM-Math/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MCM-Math/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-17T14:25:16Z',
#   'updated_at': '2019-07-17T14:25:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
# ...
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27413',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27413/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27413/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27413/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27413',
#   'id': 468437436,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk3ODY2MzQ4',
#   'number': 27413,
#   'title': 'CLN/REF: Unify Arithmetic Methods',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2019-07-16T04:10:14Z',
#   'updated_at': '2019-07-17T11:47:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27413',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27413',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27413.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27413.patch'},
#   'body': "2 goals here.\r\n\r\nFirst is to end up with a single implementation for our arithmetic ops.  By implementing the missing methods directly on DTA/PA, we make it so we don't need to special-case inside the `Index.__foo__` methods, so can dispatch to Series more directly.\r\n\r\nSecond is to get the wrapper defined in_arith_method_SERIES to the point where we can use it block-wise instead of column-wise, to address the recent perf issues.  This makes progress towards that goal by tightening up the allowed types in masked_arith_op\r\n\r\nOh, and we also get rid of a usage of values_from_object, which is adjacent to #27165 and #27167"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27411',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27411/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27411/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27411/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27411',
#   'id': 468404371,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk3ODQyNDMx',
#   'number': 27411,
#   'title': 'REF: stop allowing iNaT in TimedeltaBlock methods',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False},
#    {'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-16T01:37:56Z',
#   'updated_at': '2019-07-16T20:47:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27411',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27411',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27411.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27411.patch'},
#   'body': 'Working towards minimizing the amount of special-casing we do within internals'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27408',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27408/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27408/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27408/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/27408',
#   'id': 468368291,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjk3ODE0MjY4',
#   'number': 27408,
#   'title': 'CLN: get parts of Block.replace out of try/except',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-15T22:48:19Z',
#   'updated_at': '2019-07-16T20:34:59Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/27408',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/27408',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/27408.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/27408.patch'},
#   'body': ''},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27407',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27407/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27407/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/27407/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/27407',
#   'id': 468363434,
#   'node_id': 'MDU6SXNzdWU0NjgzNjM0MzQ=',
#   'number': 27407,
#   'title': 'ENH: Allow index names to be included in itertuples() result',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2019-07-15T22:29:25Z',
#   'updated_at': '2019-07-15T22:29:25Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nIn [1]: import pandas as pd\r\n\r\nIn [2]: df = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 20, 30, 40]},\r\n            index=pd.MultiIndex.from_product([['a', 'b'], ['c', 'd']],\r\n                                                names=['ab', 'cd']))\r\n        df\r\nOut[2]:\r\n       x   y\r\nab cd\r\na  c   1  10\r\n   d   2  20\r\nb  c   3  30\r\n   d   4  40\r\n\r\nIn [3]: for it in df.itertuples():\r\n               print(it)\r\n\r\nPandas(Index=('a', 'c'), x=1, y=10)\r\nPandas(Index=('a', 'd'), x=2, y=20)\r\nPandas(Index=('b', 'c'), x=3, y=30)\r\nPandas(Index=('b', 'd'), x=4, y=40)\r\n```\r\n#### Problem description\r\nWhen iterating through a `DataFrame`, the names of the `Index` are lost.\r\n\r\nIt would be really convenient if when a `MultiIndex` is used, the names of the `MultiIndex` were included in the result of `itertuples()`.\r\n\r\nPropose to add named argument to `itertuples()` called `nameIndex` with default value `False` to retain current behavior, and `nameIndex=True` causing output as shown below.\r\n\r\n#### Expected Output\r\n```\r\nPandas(Index=Index(ab='a', cd='c'), x=1, y=10)\r\nPandas(Index=Index(ab='a', cd='d'), x=2, y=20)\r\nPandas(Index=Index(ab='b', cd='c'), x=3, y=30)\r\nPandas(Index=Index(ab='b', cd='d'), x=4, y=40)\r\n```\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : b57d523b3006445170c865a6f5c8a5cde43e64f8\r\npython           : 3.7.3.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 60 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.None\r\n\r\npandas           : 0.25.0rc0+62.gb57d523b3\r\nnumpy            : 1.16.4\r\npytz             : 2019.1\r\ndateutil         : 2.8.0\r\npip              : 19.1.1\r\nsetuptools       : 41.0.1\r\nCython           : 0.29.11\r\npytest           : 5.0.0\r\nhypothesis       : 4.23.6\r\nsphinx           : 1.8.5\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 1.1.8\r\nlxml.etree       : 4.3.4\r\nhtml5lib         : 1.0.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.10.1\r\nIPython          : 7.6.1\r\npandas_datareader: None\r\nbs4              : 4.7.1\r\nbottleneck       : 1.2.1\r\nfastparquet      : 0.3.0\r\ngcsfs            : None\r\nlxml.etree       : 4.3.4\r\nmatplotlib       : 3.1.0\r\nnumexpr          : 2.6.9\r\nodfpy            : None\r\nopenpyxl         : 2.6.2\r\npandas_gbq       : None\r\npyarrow          : 0.11.1\r\npytables         : None\r\ns3fs             : 0.2.1\r\nscipy            : 1.2.1\r\nsqlalchemy       : 1.3.5\r\ntables           : 3.5.2\r\nxarray           : 0.12.1\r\nxlrd             : 1.2.0\r\nxlwt             : 1.3.0\r\nxlsxwriter       : 1.1.8\r\n\r\n</details>\r\n"}]

# %%
data[0]['title']
# Out:
# 'pd.to_datetime() flaw mixed behavior yielding inconsistant results'

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])

# %%
issues
# Out:
#     number                                              title  \
# 0    27454  pd.to_datetime() flaw mixed behavior yielding ...
# 1    27453                     Right merge not preserve order
# 2    27451       `Dataframe.sample()` isn't validating `frac`
# 3    27450       Why read_sas is converting strings to float?
# 4    27447  WIP: treat list of namedtuples like list of di...
# 5    27446  Is the internal twosigma refactor of window.py...
# 6    27445           BUG: avoid incorrectly inheriting result
# 7    27444  CLN: simplify maybe_convery_objects, soft_conv...
# 8    27443  TST: Add test for operations on DataFrame with...
# 9    27442  Give pandas.core.groupby.generic.DataFrameGrou...
# 10   27439  [Feature request] Add a "filter" method to Ind...
# 11   27438  BUG: maybe_convert_objects mixed datetimes and...
# 12   27437  Indexing on series where index is output from ...
# 13   27436  BUG: fix+test quantile with empty DataFrame, c...
# 14   27435  Version 0.24.2 is suddenly Python 3 only. I wa...
# 15   27431  Feature request: add option to disable columns...
# 16   27430  validate ='m:m' in dataframe.merge should have...
# 17   27428       CLN/REF: stop allowing iNaT in DatetimeBlock
# 18   27424                   Removed ABCs from pandas._typing
# 19   27423          CLN: fix build warning in c_timestamp.pyx
# 20   27421       CI: Compatibility with pytest-azurepipelines
# 21   27420  DataFrame with MultiIndex raises `TypeError` i...
# 22   27418  add some type annotations and refactor io/form...
# 23   27417               PERF: maybe_convert_objects rethink.
# 24   27415  Using a `CategoricalIndex` with interval categ...
# 25   27414                               read_csv memory leak
# 26   27413                  CLN/REF: Unify Arithmetic Methods
# 27   27411  REF: stop allowing iNaT in TimedeltaBlock methods
# 28   27408  CLN: get parts of Block.replace out of try/except
# 29   27407  ENH: Allow index names to be included in itert...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# 2                                                  []  open
# 3                                                  []  open
# 4                                                  []  open
# 5                                                  []  open
# 6                                                  []  open
# 7                                                  []  open
# 8                                                  []  open
# 9                                                  []  open
# 10  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 11  [{'id': 57296398, 'node_id': 'MDU6TGFiZWw1NzI5...  open
# 12                                                 []  open
# 13  [{'id': 57296398, 'node_id': 'MDU6TGFiZWw1NzI5...  open
# 14                                                 []  open
# 15                                                 []  open
# 16                                                 []  open
# 17  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 18  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 19  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 20  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 21                                                 []  open
# 22  [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTE...  open
# 23                                                 []  open
# 24  [{'id': 986278782, 'node_id': 'MDU6TGFiZWw5ODY...  open
# 25  [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 26  [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 27  [{'id': 76865106, 'node_id': 'MDU6TGFiZWw3Njg2...  open
# 28                                                 []  open
# 29                                                 []  open
